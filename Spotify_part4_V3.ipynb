# %% [markdown]
# # INFO-H600 : Million Playlist Dataset (Spotify) -Q.4
#
# ## Stratégie et Méthodes
#
# 1.  **Gestion des Données (Tâche 1) :** Le dataset de $35$ GB sera géré à l'aide de frameworks distribués (Dask/Spark) pour la scalabilité[cite: 9, 18].
# 2.  **Analyse Thématique (Tâche 4) :**
#     * **Vectorisation :** Nous appliquons le **Latent Dirichlet Allocation (LDA)** aux métadonnées textuelles (titres de playlists/pistes/artistes) pour extraire des **sujets thématiques** clés.
#     * **Similarité Playlist :** La similarité entre deux playlists est définie par la distance (Similarité Cosinus) entre leurs vecteurs de probabilités thématiques.

# %% [markdown]
# # Step 0 – Aller sur kaggle créer un compte et reccup le fichier avec la clé
# # Step 0.1 – Configurer l'API Kaggle dans Colab
#
# Objectif :
# - Utiliser le fichier `kaggle.json` (qui contient que la clé API) déjà uploadé dans Colab.
# - Le copier dans le dossier spécial `~/.kaggle/`.
# - Vérifier que l'API Kaggle fonctionne.
#
# Précondition :
# - Le fichier `kaggle.json` doit se trouver dans `/content/kaggle.json`
#   (tu l'as déjà uploadé via l'interface fichiers de Colab).

# %%
import os
import shutil

# Installer/mettre à jour l'API Kaggle
# !pip install -q kaggle --upgrade

# Créer le dossier .kaggle si besoin
os.makedirs("/root/.kaggle", exist_ok=True)

# Copier le kaggle.json que tu as uploadé dans /content
src = "/content/kaggle.json"
dst = "/root/.kaggle/kaggle.json"

shutil.copy(src, dst)
os.chmod(dst, 0o600)

print("✔️ kaggle.json copié et permissions configurées")

# Vérifier que l'API répond
# !kaggle -v
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.4/86.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.4/256.4 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 70.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.3/159.3 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 17.9 MB/s eta 0:00:00
# ✔️ kaggle.json copié et permissions configurées
# Kaggle API 1.8.2

# %% [markdown]
# # Step 1 – Vérifier l'accès au dataset Spotify et préparer le dossier de travail
#
# Objectif :
# - Vérifier que l'API Kaggle peut accéder au dataset "spotify-million".
# - Créer un dossier local `/content/mpd` pour stocker les fichiers JSON.
# - Ne **pas** télécharger tout le dataset, juste quelques fichiers ciblés ensuite.

# %%
# Vérifier que le dataset est accessible
# !kaggle datasets list -s "spotify-million"

# Créer le dossier de travail pour les slices qu'on va reccup après
# !mkdir -p /content/mpd

print("✔️ Dossier /content/mpd prêt")
# Out:
# ref                                                      title                                                  size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -----------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# notshrirang/spotify-million-song-dataset                 Spotify Million Song Dataset                       21735868  2022-11-21 16:48:45.780000          21833        143                1
# undefinenull/million-song-dataset-spotify-lastfm         Million Song Dataset + Spotify + Last.fm          670020079  2023-04-22 08:17:45.377000           7060         71        0.9411765
# amitanshjoshi/spotify-1million-tracks                    Spotify_1Million_Tracks                            80841459  2023-06-21 12:27:55.677000           9259        102                1
# bwandowando/3-4-million-spotify-google-store-reviews     🎸3.4 Million Spotify Google Store Reviews         273598020  2023-11-17 01:20:28.270000            640         31                1
# rodolfofigueroa/spotify-12m-songs                        Spotify 1.2M+ Songs                               102161675  2020-12-22 06:44:03.177000          10776        142        0.8235294
# mfaaris/spotify-app-reviews-2022                         Spotify App Reviews                                 4236817  2022-07-10 17:25:08.920000           9291         99                1
# joebeachcapital/57651-spotify-songs                      60000 Spotify Songs                                21501186  2024-01-23 06:48:36.383000           2782         51                1
# edumucelli/spotifys-worldwide-daily-song-ranking         Spotify's Worldwide Daily Song Ranking             45167411  2018-01-12 20:32:57.537000          15132        367        0.7352941
# adityak80/spotify-millions-playlist                      spotify-millions-playlist                        5698294450  2021-09-04 13:02:16.527000            563          6       0.29411766
# figolm10/music-dataset                                   Spotify Million Songs Dataset                      21735868  2024-01-04 09:22:47.750000             31         15       0.29411766
# mcfurland/10-m-beatport-tracks-spotify-audio-features    10+ M. Beatport Tracks / Spotify Audio Features  2273027048  2023-09-19 22:17:14.677000           2085         49                1
# olegfostenko/spotify-1-3-million-tracks-10-features      About a million Spotify tracks: 10 features       113890986  2024-05-03 18:04:39.373000             65          3                1
# olegfostenko/almost-a-million-spotify-tracks             Almost a million Spotify tracks | 2024            122623515  2024-06-03 20:25:38.070000            191          1                1
# sergeserbinenko/2-million-song-spotify-dataset           2 Million Song Spotify Dataset                    148531457  2023-04-10 08:44:51.910000            157          7            0.375
# arslanali4343/top-song-daily-ranking-of-spotifys          Top Song Daily Ranking Of Spotify's               13913201  2020-10-01 15:24:59.907000            634         90        0.9411765
# thedevastator/popularity-of-spotify-top-tracks-by-genre  Popularity of Spotify Top Tracks by Genre           9324456  2022-10-18 17:55:53.270000           1550         42        0.8235294
# astronasko/payner                                        Bulgarian popfolk songs, 2014-2020                    51667  2021-01-04 18:52:59.170000            185         19                1
# himanshuwagh/spotify-million                             spotify_million                                  5585657586  2022-08-19 07:12:12.697000           3458         14            0.375
# barirasajjad/spotify-dataset                             Spotify_dataset                                    22073301  2024-06-04 00:53:18.953000             39         16        0.4117647
# adnananam/spotify-artist-stats                           Spotify Artist Stats                                  28330  2022-09-22 03:22:44.170000           3535         51                1
# ✔️ Dossier /content/mpd prêt

# %% [markdown]
# # Step 2 V2 – Inspecter le contenu du dataset Kaggle
#
# (**UPDATE** : on ne peut pas faire -f mpd.slice.0-999.json → 404
# il faut d’abord télécharger un ou quelques gros fichiers, puis extraire seulement ce qu’on veut)
#
# Objectif :
# - Lister tous les fichiers disponibles dans le dataset `himanshuwagh/spotify-million`.
# - Voir les vrais noms de fichiers (peut-être un gros .zip ou un gros .json).
# - Choisir ensuite seulement 1 ou quelques fichiers à télécharger (pour rester sous ~5 Go).

# %%
# Lister les fichiers du dataset Spotify Million Playlist sur Kaggle
# !kaggle datasets files -d himanshuwagh/spotify-million
# Out:
# Next Page Token = CfDJ8JvX8PYzZ5dKharEO0H57fGkwtm7-O97SBp2k-fehVZUc1I2LW4FEVjXVJjn8v2UoYISDtRMOFeIjG4kcoBimyh3fLEPrd5g43mYvHiLOiEzQP6v7Uger9WtC9AVGQ0egWc5B0nv5SQ0VaGkQgiI5BehUYh1sr3yXQ
# name                                   size  creationDate
# ---------------------------------  --------  --------------------------
# README.md                              9833  2022-08-19 07:13:22.678000
# data/mpd.slice.0-999.json          34119368  2022-08-19 07:14:41.405000
# data/mpd.slice.1000-1999.json      33681395  2022-08-19 07:15:20.377000
# data/mpd.slice.10000-10999.json    33691886  2022-08-19 07:14:23.517000
# data/mpd.slice.100000-100999.json  34735676  2022-08-19 07:17:46.729000
# data/mpd.slice.101000-101999.json  33143802  2022-08-19 07:17:32.213000
# data/mpd.slice.102000-102999.json  34224525  2022-08-19 07:17:25.804000
# data/mpd.slice.103000-103999.json  32606276  2022-08-19 07:17:11.205000
# data/mpd.slice.104000-104999.json  35239288  2022-08-19 07:14:57.405000
# data/mpd.slice.105000-105999.json  33140083  2022-08-19 07:14:48.699000
# data/mpd.slice.106000-106999.json  34266249  2022-08-19 07:15:13.919000
# data/mpd.slice.107000-107999.json  33037230  2022-08-19 07:15:04.868000
# data/mpd.slice.108000-108999.json  34903494  2022-08-19 07:16:47.337000
# data/mpd.slice.109000-109999.json  34747270  2022-08-19 07:16:58.554000
# data/mpd.slice.11000-11999.json    32833224  2022-08-19 07:15:50.508000
# data/mpd.slice.110000-110999.json  33689074  2022-08-19 07:15:49.958000
# data/mpd.slice.111000-111999.json  33747389  2022-08-19 07:15:39.469000
# data/mpd.slice.112000-112999.json  33547633  2022-08-19 07:15:33.003000
# data/mpd.slice.113000-113999.json  33936509  2022-08-19 07:15:22.070000
# data/mpd.slice.114000-114999.json  33946205  2022-08-19 07:13:32.339000

# %%
dataset_name = "himanshuwagh/spotify-million"
target_dir = "/content/mpd"

# !mkdir -p $target_dir
# !kaggle datasets download -d $dataset_name -f README.md -p $target_dir --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading README.md to /content/mpd
#   0% 0.00/9.60k [00:00<?, ?B/s]
# 100% 9.60k/9.60k [00:00<00:00, 14.3MB/s]

# %% [markdown]
# # Step 2.1 – Télécharger seulement ~4–5 Go de fichiers `mpd.slice.*.json` (2min to download)
#
# Objectif :
# - Ne PAS télécharger tout le dataset.
# - Télécharger seulement un sous-ensemble de fichiers `data/mpd.slice.*.json`.
# - Chaque slice fait ≈ 33–35 Mo → avec ~120 slices on obtient ≈ 4 Go.
#
# Important :
# - Dans ce dataset Kaggle, les noms de fichiers incluent le préfixe `data/`,
#   par exemple : `data/mpd.slice.0-999.json`.
# - Il faut donc utiliser ce nom complet dans l’option `-f` de l’API Kaggle.
# - Avec `--unzip`, les fichiers seront extraits dans `/content/mpd/data/`.

# %%
import math
from pathlib import Path

dataset_name = "himanshuwagh/spotify-million"
target_dir = "/content/mpd"

# Nombre de slices à télécharger (ajuste si besoin)
N_SLICES = 120  # 120 slices * ~34 Mo ≈ 4 Go

# Créer le dossier cible
# !mkdir -p $target_dir

print(f"Téléchargement de {N_SLICES} slices dans {target_dir} ...")

for i in range(N_SLICES):
    start = i * 1000
    end = start + 999
    kaggle_fname = f"data/mpd.slice.{start}-{end}.json"  # ⚠️ avec 'data/' devant

    print(f"\n⏬ Downloading slice {i+1}/{N_SLICES}: {kaggle_fname}")
    # -f : nom EXACT du fichier vu dans "kaggle datasets files"
    # --unzip : on extrait directement le .json dans /content/mpd/data/
    # !kaggle datasets download -d $dataset_name -f $kaggle_fname -p $target_dir --unzip
# Out:
# Téléchargement de 120 slices dans /content/mpd ...
#
# ⏬ Downloading slice 1/120: data/mpd.slice.0-999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.0-999.json.zip to /content/mpd
#   0% 0.00/5.43M [00:00<?, ?B/s]
# 100% 5.43M/5.43M [00:00<00:00, 90.7MB/s]
#
# ⏬ Downloading slice 2/120: data/mpd.slice.1000-1999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.1000-1999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 115MB/s]
#
# ⏬ Downloading slice 3/120: data/mpd.slice.2000-2999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.2000-2999.json.zip to /content/mpd
#   0% 0.00/5.27M [00:00<?, ?B/s]
# 100% 5.27M/5.27M [00:00<00:00, 111MB/s]
#
# ⏬ Downloading slice 4/120: data/mpd.slice.3000-3999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.3000-3999.json.zip to /content/mpd
#   0% 0.00/5.35M [00:00<?, ?B/s]
# 100% 5.35M/5.35M [00:00<00:00, 58.7MB/s]
#
# ⏬ Downloading slice 5/120: data/mpd.slice.4000-4999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.4000-4999.json.zip to /content/mpd
#   0% 0.00/5.49M [00:00<?, ?B/s]
# 100% 5.49M/5.49M [00:00<00:00, 74.7MB/s]
#
# ⏬ Downloading slice 6/120: data/mpd.slice.5000-5999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.5000-5999.json.zip to /content/mpd
#   0% 0.00/5.39M [00:00<?, ?B/s]
# 100% 5.39M/5.39M [00:00<00:00, 103MB/s]
#
# ⏬ Downloading slice 7/120: data/mpd.slice.6000-6999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.6000-6999.json.zip to /content/mpd
#   0% 0.00/5.30M [00:00<?, ?B/s]
# 100% 5.30M/5.30M [00:00<00:00, 98.5MB/s]
#
# ⏬ Downloading slice 8/120: data/mpd.slice.7000-7999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.7000-7999.json.zip to /content/mpd
# 100% 5.42M/5.42M [00:00<00:00, 56.2MB/s]
# 100% 5.42M/5.42M [00:00<00:00, 56.0MB/s]
#
# ⏬ Downloading slice 9/120: data/mpd.slice.8000-8999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.8000-8999.json.zip to /content/mpd
#  94% 5.00M/5.31M [00:00<00:00, 40.6MB/s]
# 100% 5.31M/5.31M [00:00<00:00, 42.7MB/s]
#
# ⏬ Downloading slice 10/120: data/mpd.slice.9000-9999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.9000-9999.json.zip to /content/mpd
#   0% 0.00/5.12M [00:00<?, ?B/s]
# 100% 5.12M/5.12M [00:00<00:00, 130MB/s]
#
# ⏬ Downloading slice 11/120: data/mpd.slice.10000-10999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.10000-10999.json.zip to /content/mpd
#   0% 0.00/5.35M [00:00<?, ?B/s]
# 100% 5.35M/5.35M [00:00<00:00, 92.6MB/s]
#
# ⏬ Downloading slice 12/120: data/mpd.slice.11000-11999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.11000-11999.json.zip to /content/mpd
#   0% 0.00/5.23M [00:00<?, ?B/s]
# 100% 5.23M/5.23M [00:00<00:00, 107MB/s]
#
# ⏬ Downloading slice 13/120: data/mpd.slice.12000-12999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.12000-12999.json.zip to /content/mpd
#   0% 0.00/5.56M [00:00<?, ?B/s]
# 100% 5.56M/5.56M [00:00<00:00, 69.5MB/s]
#
# ⏬ Downloading slice 14/120: data/mpd.slice.13000-13999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.13000-13999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 92.0MB/s]
#
# ⏬ Downloading slice 15/120: data/mpd.slice.14000-14999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.14000-14999.json.zip to /content/mpd
#  93% 5.00M/5.37M [00:00<00:00, 35.1MB/s]
# 100% 5.37M/5.37M [00:00<00:00, 37.3MB/s]
#
# ⏬ Downloading slice 16/120: data/mpd.slice.15000-15999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.15000-15999.json.zip to /content/mpd
#  57% 3.00M/5.27M [00:00<00:00, 12.2MB/s]
# 100% 5.27M/5.27M [00:00<00:00, 20.5MB/s]
#
# ⏬ Downloading slice 17/120: data/mpd.slice.16000-16999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.16000-16999.json.zip to /content/mpd
#   0% 0.00/5.39M [00:00<?, ?B/s]
# 100% 5.39M/5.39M [00:00<00:00, 80.6MB/s]
#
# ⏬ Downloading slice 18/120: data/mpd.slice.17000-17999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.17000-17999.json.zip to /content/mpd
#   0% 0.00/5.52M [00:00<?, ?B/s]
# 100% 5.52M/5.52M [00:00<00:00, 94.7MB/s]
#
# ⏬ Downloading slice 19/120: data/mpd.slice.18000-18999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.18000-18999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 134MB/s]
#
# ⏬ Downloading slice 20/120: data/mpd.slice.19000-19999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.19000-19999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 179MB/s]
#
# ⏬ Downloading slice 21/120: data/mpd.slice.20000-20999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.20000-20999.json.zip to /content/mpd
#   0% 0.00/5.34M [00:00<?, ?B/s]
# 100% 5.34M/5.34M [00:00<00:00, 155MB/s]
#
# ⏬ Downloading slice 22/120: data/mpd.slice.21000-21999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.21000-21999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 69.3MB/s]
#
# ⏬ Downloading slice 23/120: data/mpd.slice.22000-22999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.22000-22999.json.zip to /content/mpd
#   0% 0.00/5.61M [00:00<?, ?B/s]
# 100% 5.61M/5.61M [00:00<00:00, 127MB/s]
#
# ⏬ Downloading slice 24/120: data/mpd.slice.23000-23999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.23000-23999.json.zip to /content/mpd
#   0% 0.00/5.42M [00:00<?, ?B/s]
# 100% 5.42M/5.42M [00:00<00:00, 63.9MB/s]
#
# ⏬ Downloading slice 25/120: data/mpd.slice.24000-24999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.24000-24999.json.zip to /content/mpd
#   0% 0.00/5.35M [00:00<?, ?B/s]
# 100% 5.35M/5.35M [00:00<00:00, 92.3MB/s]
#
# ⏬ Downloading slice 26/120: data/mpd.slice.25000-25999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.25000-25999.json.zip to /content/mpd
#   0% 0.00/5.52M [00:00<?, ?B/s]
# 100% 5.52M/5.52M [00:00<00:00, 75.4MB/s]
#
# ⏬ Downloading slice 27/120: data/mpd.slice.26000-26999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.26000-26999.json.zip to /content/mpd
#   0% 0.00/5.21M [00:00<?, ?B/s]
# 100% 5.21M/5.21M [00:00<00:00, 100MB/s]
#
# ⏬ Downloading slice 28/120: data/mpd.slice.27000-27999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.27000-27999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 62.6MB/s]
#
# ⏬ Downloading slice 29/120: data/mpd.slice.28000-28999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.28000-28999.json.zip to /content/mpd
#   0% 0.00/5.48M [00:00<?, ?B/s]
# 100% 5.48M/5.48M [00:00<00:00, 84.8MB/s]
#
# ⏬ Downloading slice 30/120: data/mpd.slice.29000-29999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.29000-29999.json.zip to /content/mpd
#  93% 5.00M/5.37M [00:00<00:00, 52.3MB/s]
# 100% 5.37M/5.37M [00:00<00:00, 55.3MB/s]
#
# ⏬ Downloading slice 31/120: data/mpd.slice.30000-30999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.30000-30999.json.zip to /content/mpd
#   0% 0.00/5.53M [00:00<?, ?B/s]
# 100% 5.53M/5.53M [00:00<00:00, 82.5MB/s]
#
# ⏬ Downloading slice 32/120: data/mpd.slice.31000-31999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.31000-31999.json.zip to /content/mpd
#   0% 0.00/5.16M [00:00<?, ?B/s]
# 100% 5.16M/5.16M [00:00<00:00, 77.3MB/s]
#
# ⏬ Downloading slice 33/120: data/mpd.slice.32000-32999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.32000-32999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 72.5MB/s]
#
# ⏬ Downloading slice 34/120: data/mpd.slice.33000-33999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.33000-33999.json.zip to /content/mpd
#   0% 0.00/5.32M [00:00<?, ?B/s]
# 100% 5.32M/5.32M [00:00<00:00, 94.6MB/s]
#
# ⏬ Downloading slice 35/120: data/mpd.slice.34000-34999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.34000-34999.json.zip to /content/mpd
#   0% 0.00/5.34M [00:00<?, ?B/s]
# 100% 5.34M/5.34M [00:00<00:00, 111MB/s]
#
# ⏬ Downloading slice 36/120: data/mpd.slice.35000-35999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.35000-35999.json.zip to /content/mpd
#  93% 5.00M/5.36M [00:00<00:00, 47.5MB/s]
# 100% 5.36M/5.36M [00:00<00:00, 50.3MB/s]
#
# ⏬ Downloading slice 37/120: data/mpd.slice.36000-36999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.36000-36999.json.zip to /content/mpd
#   0% 0.00/5.29M [00:00<?, ?B/s]
# 100% 5.29M/5.29M [00:00<00:00, 79.7MB/s]
#
# ⏬ Downloading slice 38/120: data/mpd.slice.37000-37999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.37000-37999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 124MB/s]
#
# ⏬ Downloading slice 39/120: data/mpd.slice.38000-38999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.38000-38999.json.zip to /content/mpd
#   0% 0.00/5.06M [00:00<?, ?B/s]
# 100% 5.06M/5.06M [00:00<00:00, 167MB/s]
#
# ⏬ Downloading slice 40/120: data/mpd.slice.39000-39999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.39000-39999.json.zip to /content/mpd
#  93% 5.00M/5.39M [00:00<00:00, 52.0MB/s]
# 100% 5.39M/5.39M [00:00<00:00, 55.3MB/s]
#
# ⏬ Downloading slice 41/120: data/mpd.slice.40000-40999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.40000-40999.json.zip to /content/mpd
#   0% 0.00/5.28M [00:00<?, ?B/s]
# 100% 5.28M/5.28M [00:00<00:00, 80.3MB/s]
#
# ⏬ Downloading slice 42/120: data/mpd.slice.41000-41999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.41000-41999.json.zip to /content/mpd
#   0% 0.00/5.44M [00:00<?, ?B/s]
# 100% 5.44M/5.44M [00:00<00:00, 101MB/s]
#
# ⏬ Downloading slice 43/120: data/mpd.slice.42000-42999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.42000-42999.json.zip to /content/mpd
#   0% 0.00/5.44M [00:00<?, ?B/s]
# 100% 5.44M/5.44M [00:00<00:00, 96.4MB/s]
#
# ⏬ Downloading slice 44/120: data/mpd.slice.43000-43999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.43000-43999.json.zip to /content/mpd
#   0% 0.00/5.44M [00:00<?, ?B/s]
# 100% 5.44M/5.44M [00:00<00:00, 109MB/s]
#
# ⏬ Downloading slice 45/120: data/mpd.slice.44000-44999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.44000-44999.json.zip to /content/mpd
#   0% 0.00/5.51M [00:00<?, ?B/s]
# 100% 5.51M/5.51M [00:00<00:00, 79.8MB/s]
#
# ⏬ Downloading slice 46/120: data/mpd.slice.45000-45999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.45000-45999.json.zip to /content/mpd
#  89% 5.00M/5.60M [00:00<00:00, 33.9MB/s]
# 100% 5.60M/5.60M [00:00<00:00, 37.4MB/s]
#
# ⏬ Downloading slice 47/120: data/mpd.slice.46000-46999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.46000-46999.json.zip to /content/mpd
#   0% 0.00/5.24M [00:00<?, ?B/s]
# 100% 5.24M/5.24M [00:00<00:00, 56.6MB/s]
#
# ⏬ Downloading slice 48/120: data/mpd.slice.47000-47999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.47000-47999.json.zip to /content/mpd
#   0% 0.00/5.37M [00:00<?, ?B/s]
# 100% 5.37M/5.37M [00:00<00:00, 99.8MB/s]
#
# ⏬ Downloading slice 49/120: data/mpd.slice.48000-48999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.48000-48999.json.zip to /content/mpd
#  93% 5.00M/5.36M [00:00<00:00, 49.1MB/s]
# 100% 5.36M/5.36M [00:00<00:00, 51.8MB/s]
#
# ⏬ Downloading slice 50/120: data/mpd.slice.49000-49999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.49000-49999.json.zip to /content/mpd
#   0% 0.00/5.32M [00:00<?, ?B/s]
# 100% 5.32M/5.32M [00:00<00:00, 74.5MB/s]
#
# ⏬ Downloading slice 51/120: data/mpd.slice.50000-50999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.50000-50999.json.zip to /content/mpd
#  96% 5.00M/5.21M [00:00<00:00, 24.6MB/s]
# 100% 5.21M/5.21M [00:00<00:00, 25.5MB/s]
#
# ⏬ Downloading slice 52/120: data/mpd.slice.51000-51999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.51000-51999.json.zip to /content/mpd
#   0% 0.00/5.58M [00:00<?, ?B/s]
# 100% 5.58M/5.58M [00:00<00:00, 71.9MB/s]
#
# ⏬ Downloading slice 53/120: data/mpd.slice.52000-52999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.52000-52999.json.zip to /content/mpd
#  96% 5.00M/5.21M [00:00<00:00, 35.2MB/s]
# 100% 5.21M/5.21M [00:00<00:00, 36.4MB/s]
#
# ⏬ Downloading slice 54/120: data/mpd.slice.53000-53999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.53000-53999.json.zip to /content/mpd
#   0% 0.00/5.20M [00:00<?, ?B/s]
# 100% 5.20M/5.20M [00:00<00:00, 69.6MB/s]
#
# ⏬ Downloading slice 55/120: data/mpd.slice.54000-54999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.54000-54999.json.zip to /content/mpd
#   0% 0.00/5.23M [00:00<?, ?B/s]
# 100% 5.23M/5.23M [00:00<00:00, 73.3MB/s]
#
# ⏬ Downloading slice 56/120: data/mpd.slice.55000-55999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.55000-55999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 82.8MB/s]
#
# ⏬ Downloading slice 57/120: data/mpd.slice.56000-56999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.56000-56999.json.zip to /content/mpd
#  93% 5.00M/5.36M [00:00<00:00, 50.9MB/s]
# 100% 5.36M/5.36M [00:00<00:00, 53.7MB/s]
#
# ⏬ Downloading slice 58/120: data/mpd.slice.57000-57999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.57000-57999.json.zip to /content/mpd
#  55% 3.00M/5.47M [00:00<00:00, 12.5MB/s]
# 100% 5.47M/5.47M [00:00<00:00, 22.2MB/s]
#
# ⏬ Downloading slice 59/120: data/mpd.slice.58000-58999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.58000-58999.json.zip to /content/mpd
#   0% 0.00/5.50M [00:00<?, ?B/s]
# 100% 5.50M/5.50M [00:00<00:00, 240MB/s]
#
# ⏬ Downloading slice 60/120: data/mpd.slice.59000-59999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.59000-59999.json.zip to /content/mpd
#   0% 0.00/5.39M [00:00<?, ?B/s]
# 100% 5.39M/5.39M [00:00<00:00, 76.7MB/s]
#
# ⏬ Downloading slice 61/120: data/mpd.slice.60000-60999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.60000-60999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 92.9MB/s]
#
# ⏬ Downloading slice 62/120: data/mpd.slice.61000-61999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.61000-61999.json.zip to /content/mpd
#   0% 0.00/5.27M [00:00<?, ?B/s]
# 100% 5.27M/5.27M [00:00<00:00, 62.8MB/s]
#
# ⏬ Downloading slice 63/120: data/mpd.slice.62000-62999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.62000-62999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 82.2MB/s]
#
# ⏬ Downloading slice 64/120: data/mpd.slice.63000-63999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.63000-63999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 93.7MB/s]
#
# ⏬ Downloading slice 65/120: data/mpd.slice.64000-64999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.64000-64999.json.zip to /content/mpd
#   0% 0.00/5.25M [00:00<?, ?B/s]
# 100% 5.25M/5.25M [00:00<00:00, 76.7MB/s]
#
# ⏬ Downloading slice 66/120: data/mpd.slice.65000-65999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.65000-65999.json.zip to /content/mpd
#  93% 5.00M/5.39M [00:00<00:00, 29.3MB/s]
# 100% 5.39M/5.39M [00:00<00:00, 31.4MB/s]
#
# ⏬ Downloading slice 67/120: data/mpd.slice.66000-66999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.66000-66999.json.zip to /content/mpd
#   0% 0.00/5.26M [00:00<?, ?B/s]
# 100% 5.26M/5.26M [00:00<00:00, 81.7MB/s]
#
# ⏬ Downloading slice 68/120: data/mpd.slice.67000-67999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.67000-67999.json.zip to /content/mpd
#  96% 5.00M/5.19M [00:00<00:00, 50.2MB/s]
# 100% 5.19M/5.19M [00:00<00:00, 51.7MB/s]
#
# ⏬ Downloading slice 69/120: data/mpd.slice.68000-68999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.68000-68999.json.zip to /content/mpd
#   0% 0.00/5.58M [00:00<?, ?B/s]
# 100% 5.58M/5.58M [00:00<00:00, 60.8MB/s]
#
# ⏬ Downloading slice 70/120: data/mpd.slice.69000-69999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.69000-69999.json.zip to /content/mpd
#  92% 5.00M/5.45M [00:00<00:00, 31.4MB/s]
# 100% 5.45M/5.45M [00:00<00:00, 33.9MB/s]
#
# ⏬ Downloading slice 71/120: data/mpd.slice.70000-70999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.70000-70999.json.zip to /content/mpd
#   0% 0.00/5.27M [00:00<?, ?B/s]
# 100% 5.27M/5.27M [00:00<00:00, 88.7MB/s]
#
# ⏬ Downloading slice 72/120: data/mpd.slice.71000-71999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.71000-71999.json.zip to /content/mpd
#   0% 0.00/5.17M [00:00<?, ?B/s]
# 100% 5.17M/5.17M [00:00<00:00, 61.4MB/s]
#
# ⏬ Downloading slice 73/120: data/mpd.slice.72000-72999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.72000-72999.json.zip to /content/mpd
#   0% 0.00/5.50M [00:00<?, ?B/s]
# 100% 5.50M/5.50M [00:00<00:00, 71.9MB/s]
#
# ⏬ Downloading slice 74/120: data/mpd.slice.73000-73999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.73000-73999.json.zip to /content/mpd
#   0% 0.00/5.18M [00:00<?, ?B/s]
# 100% 5.18M/5.18M [00:00<00:00, 61.2MB/s]
#
# ⏬ Downloading slice 75/120: data/mpd.slice.74000-74999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.74000-74999.json.zip to /content/mpd
#   0% 0.00/5.63M [00:00<?, ?B/s]
# 100% 5.63M/5.63M [00:00<00:00, 80.3MB/s]
#
# ⏬ Downloading slice 76/120: data/mpd.slice.75000-75999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.75000-75999.json.zip to /content/mpd
#   0% 0.00/5.35M [00:00<?, ?B/s]
# 100% 5.35M/5.35M [00:00<00:00, 98.9MB/s]
#
# ⏬ Downloading slice 77/120: data/mpd.slice.76000-76999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.76000-76999.json.zip to /content/mpd
#   0% 0.00/5.57M [00:00<?, ?B/s]
# 100% 5.57M/5.57M [00:00<00:00, 124MB/s]
#
# ⏬ Downloading slice 78/120: data/mpd.slice.77000-77999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.77000-77999.json.zip to /content/mpd
#  92% 5.00M/5.43M [00:00<00:00, 49.8MB/s]
# 100% 5.43M/5.43M [00:00<00:00, 53.2MB/s]
#
# ⏬ Downloading slice 79/120: data/mpd.slice.78000-78999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.78000-78999.json.zip to /content/mpd
#   0% 0.00/5.37M [00:00<?, ?B/s]
# 100% 5.37M/5.37M [00:00<00:00, 69.2MB/s]
#
# ⏬ Downloading slice 80/120: data/mpd.slice.79000-79999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.79000-79999.json.zip to /content/mpd
#   0% 0.00/5.18M [00:00<?, ?B/s]
# 100% 5.18M/5.18M [00:00<00:00, 89.0MB/s]
#
# ⏬ Downloading slice 81/120: data/mpd.slice.80000-80999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.80000-80999.json.zip to /content/mpd
#   0% 0.00/5.17M [00:00<?, ?B/s]
# 100% 5.17M/5.17M [00:00<00:00, 99.3MB/s]
#
# ⏬ Downloading slice 82/120: data/mpd.slice.81000-81999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.81000-81999.json.zip to /content/mpd
#   0% 0.00/5.15M [00:00<?, ?B/s]
# 100% 5.15M/5.15M [00:00<00:00, 60.9MB/s]
#
# ⏬ Downloading slice 83/120: data/mpd.slice.82000-82999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.82000-82999.json.zip to /content/mpd
#   0% 0.00/5.47M [00:00<?, ?B/s]
# 100% 5.47M/5.47M [00:00<00:00, 94.0MB/s]
#
# ⏬ Downloading slice 84/120: data/mpd.slice.83000-83999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.83000-83999.json.zip to /content/mpd
#  19% 1.00M/5.17M [00:00<00:00, 8.15MB/s]
# 100% 5.17M/5.17M [00:00<00:00, 30.6MB/s]
#
# ⏬ Downloading slice 85/120: data/mpd.slice.84000-84999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.84000-84999.json.zip to /content/mpd
#   0% 0.00/5.35M [00:00<?, ?B/s]
# 100% 5.35M/5.35M [00:00<00:00, 76.8MB/s]
#
# ⏬ Downloading slice 86/120: data/mpd.slice.85000-85999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.85000-85999.json.zip to /content/mpd
#   0% 0.00/5.52M [00:00<?, ?B/s]
# 100% 5.52M/5.52M [00:00<00:00, 101MB/s]
#
# ⏬ Downloading slice 87/120: data/mpd.slice.86000-86999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.86000-86999.json.zip to /content/mpd
#   0% 0.00/5.18M [00:00<?, ?B/s]
# 100% 5.18M/5.18M [00:00<00:00, 83.1MB/s]
#
# ⏬ Downloading slice 88/120: data/mpd.slice.87000-87999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.87000-87999.json.zip to /content/mpd
#   0% 0.00/5.39M [00:00<?, ?B/s]
# 100% 5.39M/5.39M [00:00<00:00, 172MB/s]
#
# ⏬ Downloading slice 89/120: data/mpd.slice.88000-88999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.88000-88999.json.zip to /content/mpd
#   0% 0.00/5.23M [00:00<?, ?B/s]
# 100% 5.23M/5.23M [00:00<00:00, 67.0MB/s]
#
# ⏬ Downloading slice 90/120: data/mpd.slice.89000-89999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.89000-89999.json.zip to /content/mpd
#   0% 0.00/5.16M [00:00<?, ?B/s]
# 100% 5.16M/5.16M [00:00<00:00, 95.9MB/s]
#
# ⏬ Downloading slice 91/120: data/mpd.slice.90000-90999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.90000-90999.json.zip to /content/mpd
#   0% 0.00/5.38M [00:00<?, ?B/s]
# 100% 5.38M/5.38M [00:00<00:00, 79.4MB/s]
#
# ⏬ Downloading slice 92/120: data/mpd.slice.91000-91999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.91000-91999.json.zip to /content/mpd
#   0% 0.00/5.42M [00:00<?, ?B/s]
# 100% 5.42M/5.42M [00:00<00:00, 61.1MB/s]
#
# ⏬ Downloading slice 93/120: data/mpd.slice.92000-92999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.92000-92999.json.zip to /content/mpd
#   0% 0.00/5.08M [00:00<?, ?B/s]
# 100% 5.08M/5.08M [00:00<00:00, 113MB/s]
#
# ⏬ Downloading slice 94/120: data/mpd.slice.93000-93999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.93000-93999.json.zip to /content/mpd
#   0% 0.00/5.55M [00:00<?, ?B/s]
# 100% 5.55M/5.55M [00:00<00:00, 160MB/s]
#
# ⏬ Downloading slice 95/120: data/mpd.slice.94000-94999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.94000-94999.json.zip to /content/mpd
#   0% 0.00/5.24M [00:00<?, ?B/s]
# 100% 5.24M/5.24M [00:00<00:00, 242MB/s]
#
# ⏬ Downloading slice 96/120: data/mpd.slice.95000-95999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.95000-95999.json.zip to /content/mpd
#   0% 0.00/5.46M [00:00<?, ?B/s]
# 100% 5.46M/5.46M [00:00<00:00, 143MB/s]
#
# ⏬ Downloading slice 97/120: data/mpd.slice.96000-96999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.96000-96999.json.zip to /content/mpd
#   0% 0.00/5.17M [00:00<?, ?B/s]
# 100% 5.17M/5.17M [00:00<00:00, 224MB/s]
#
# ⏬ Downloading slice 98/120: data/mpd.slice.97000-97999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.97000-97999.json.zip to /content/mpd
#  94% 5.00M/5.31M [00:00<00:00, 50.8MB/s]
# 100% 5.31M/5.31M [00:00<00:00, 53.2MB/s]
#
# ⏬ Downloading slice 99/120: data/mpd.slice.98000-98999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.98000-98999.json.zip to /content/mpd
#   0% 0.00/5.30M [00:00<?, ?B/s]
# 100% 5.30M/5.30M [00:00<00:00, 100MB/s]
#
# ⏬ Downloading slice 100/120: data/mpd.slice.99000-99999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.99000-99999.json.zip to /content/mpd
#   0% 0.00/5.56M [00:00<?, ?B/s]
# 100% 5.56M/5.56M [00:00<00:00, 96.7MB/s]
#
# ⏬ Downloading slice 101/120: data/mpd.slice.100000-100999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.100000-100999.json.zip to /content/mpd
#   0% 0.00/5.45M [00:00<?, ?B/s]
# 100% 5.45M/5.45M [00:00<00:00, 101MB/s]
#
# ⏬ Downloading slice 102/120: data/mpd.slice.101000-101999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.101000-101999.json.zip to /content/mpd
#  95% 5.00M/5.29M [00:00<00:00, 51.9MB/s]
# 100% 5.29M/5.29M [00:00<00:00, 54.3MB/s]
#
# ⏬ Downloading slice 103/120: data/mpd.slice.102000-102999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.102000-102999.json.zip to /content/mpd
#  92% 5.00M/5.42M [00:00<00:00, 50.7MB/s]
# 100% 5.42M/5.42M [00:00<00:00, 54.1MB/s]
#
# ⏬ Downloading slice 104/120: data/mpd.slice.103000-103999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.103000-103999.json.zip to /content/mpd
#   0% 0.00/5.14M [00:00<?, ?B/s]
# 100% 5.14M/5.14M [00:00<00:00, 103MB/s]
#
# ⏬ Downloading slice 105/120: data/mpd.slice.104000-104999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.104000-104999.json.zip to /content/mpd
#   0% 0.00/5.58M [00:00<?, ?B/s]
# 100% 5.58M/5.58M [00:00<00:00, 86.2MB/s]
#
# ⏬ Downloading slice 106/120: data/mpd.slice.105000-105999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.105000-105999.json.zip to /content/mpd
#  57% 3.00M/5.23M [00:00<00:00, 22.6MB/s]
# 100% 5.23M/5.23M [00:00<00:00, 37.6MB/s]
#
# ⏬ Downloading slice 107/120: data/mpd.slice.106000-106999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.106000-106999.json.zip to /content/mpd
#   0% 0.00/5.45M [00:00<?, ?B/s]
# 100% 5.45M/5.45M [00:00<00:00, 77.1MB/s]
#
# ⏬ Downloading slice 108/120: data/mpd.slice.107000-107999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.107000-107999.json.zip to /content/mpd
#   0% 0.00/5.24M [00:00<?, ?B/s]
# 100% 5.24M/5.24M [00:00<00:00, 98.5MB/s]
#
# ⏬ Downloading slice 109/120: data/mpd.slice.108000-108999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.108000-108999.json.zip to /content/mpd
#  91% 5.00M/5.52M [00:00<00:00, 46.8MB/s]
# 100% 5.52M/5.52M [00:00<00:00, 50.8MB/s]
#
# ⏬ Downloading slice 110/120: data/mpd.slice.109000-109999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.109000-109999.json.zip to /content/mpd
#   0% 0.00/5.51M [00:00<?, ?B/s]
# 100% 5.51M/5.51M [00:00<00:00, 77.0MB/s]
#
# ⏬ Downloading slice 111/120: data/mpd.slice.110000-110999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.110000-110999.json.zip to /content/mpd
#   0% 0.00/5.39M [00:00<?, ?B/s]
# 100% 5.39M/5.39M [00:00<00:00, 109MB/s]
#
# ⏬ Downloading slice 112/120: data/mpd.slice.111000-111999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.111000-111999.json.zip to /content/mpd
#   0% 0.00/5.33M [00:00<?, ?B/s]
# 100% 5.33M/5.33M [00:00<00:00, 90.7MB/s]
#
# ⏬ Downloading slice 113/120: data/mpd.slice.112000-112999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.112000-112999.json.zip to /content/mpd
#   0% 0.00/5.28M [00:00<?, ?B/s]
# 100% 5.28M/5.28M [00:00<00:00, 83.2MB/s]
#
# ⏬ Downloading slice 114/120: data/mpd.slice.113000-113999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.113000-113999.json.zip to /content/mpd
#  93% 5.00M/5.38M [00:00<00:00, 16.2MB/s]
# 100% 5.38M/5.38M [00:00<00:00, 17.4MB/s]
#
# ⏬ Downloading slice 115/120: data/mpd.slice.114000-114999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.114000-114999.json.zip to /content/mpd
#   0% 0.00/5.32M [00:00<?, ?B/s]
# 100% 5.32M/5.32M [00:00<00:00, 75.3MB/s]
#
# ⏬ Downloading slice 116/120: data/mpd.slice.115000-115999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.115000-115999.json.zip to /content/mpd
#  94% 5.00M/5.34M [00:00<00:00, 51.8MB/s]
# 100% 5.34M/5.34M [00:00<00:00, 53.4MB/s]
#
# ⏬ Downloading slice 117/120: data/mpd.slice.116000-116999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.116000-116999.json.zip to /content/mpd
#   0% 0.00/5.26M [00:00<?, ?B/s]
# 100% 5.26M/5.26M [00:00<00:00, 121MB/s]
#
# ⏬ Downloading slice 118/120: data/mpd.slice.117000-117999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.117000-117999.json.zip to /content/mpd
#  93% 5.00M/5.38M [00:00<00:00, 51.2MB/s]
# 100% 5.38M/5.38M [00:00<00:00, 54.4MB/s]
#
# ⏬ Downloading slice 119/120: data/mpd.slice.118000-118999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.118000-118999.json.zip to /content/mpd
#   0% 0.00/5.54M [00:00<?, ?B/s]
# 100% 5.54M/5.54M [00:00<00:00, 86.6MB/s]
#
# ⏬ Downloading slice 120/120: data/mpd.slice.119000-119999.json
# Dataset URL: https://www.kaggle.com/datasets/himanshuwagh/spotify-million
# License(s): unknown
# Downloading mpd.slice.119000-119999.json.zip to /content/mpd
#  55% 3.00M/5.42M [00:00<00:00, 26.1MB/s]
# 100% 5.42M/5.42M [00:00<00:00, 44.6MB/s]

# %% [markdown]
# # Step 3 – Dézipper tous les fichiers mpd.slice.*.json.zip
#
# Objectif :
# - Extraire chaque fichier `mpd.slice.*.json` du ZIP téléchargé.
# - Les placer dans le dossier `/content/mpd/`.
# - Vérifier ensuite combien de `.json` ont été extraits et leur taille totale.
#
# Après cette étape :
# - On doit voir des fichiers comme : `/content/mpd/mpd.slice.0-999.json`

# %%
import zipfile
from pathlib import Path

mpd_dir = Path("/content/mpd")

# Trouver tous les zip
zip_files = sorted(mpd_dir.glob("*.zip"))

print(f"Nombre de ZIP trouvés : {len(zip_files)}")

# Extraction
for z in zip_files:
    print(f"📦 Unzipping : {z.name}")
    with zipfile.ZipFile(z, 'r') as zip_ref:
        zip_ref.extractall(mpd_dir)

print("✔️ Extraction terminée")

# Vérifier la présence des .json
json_files = sorted(mpd_dir.glob("*.json"))
print(f"\nNombre de fichiers JSON extraits : {len(json_files)}")
print("Exemples :")
for p in json_files[:5]:
    print(" -", p.name)

# Taille totale
total_bytes = sum(p.stat().st_size for p in json_files)
total_gb = total_bytes / (1024**3)
print(f"\nTaille totale des JSON ≈ {total_gb:.2f} Go")
# Out:
# Nombre de ZIP trouvés : 120
# 📦 Unzipping : mpd.slice.0-999.json.zip
# 📦 Unzipping : mpd.slice.1000-1999.json.zip
# 📦 Unzipping : mpd.slice.10000-10999.json.zip
# 📦 Unzipping : mpd.slice.100000-100999.json.zip
# 📦 Unzipping : mpd.slice.101000-101999.json.zip
# 📦 Unzipping : mpd.slice.102000-102999.json.zip
# 📦 Unzipping : mpd.slice.103000-103999.json.zip
# 📦 Unzipping : mpd.slice.104000-104999.json.zip
# 📦 Unzipping : mpd.slice.105000-105999.json.zip
# 📦 Unzipping : mpd.slice.106000-106999.json.zip
# 📦 Unzipping : mpd.slice.107000-107999.json.zip
# 📦 Unzipping : mpd.slice.108000-108999.json.zip
# 📦 Unzipping : mpd.slice.109000-109999.json.zip
# 📦 Unzipping : mpd.slice.11000-11999.json.zip
# 📦 Unzipping : mpd.slice.110000-110999.json.zip
# 📦 Unzipping : mpd.slice.111000-111999.json.zip
# 📦 Unzipping : mpd.slice.112000-112999.json.zip
# 📦 Unzipping : mpd.slice.113000-113999.json.zip
# 📦 Unzipping : mpd.slice.114000-114999.json.zip
# 📦 Unzipping : mpd.slice.115000-115999.json.zip
# 📦 Unzipping : mpd.slice.116000-116999.json.zip
# 📦 Unzipping : mpd.slice.117000-117999.json.zip
# 📦 Unzipping : mpd.slice.118000-118999.json.zip
# 📦 Unzipping : mpd.slice.119000-119999.json.zip
# 📦 Unzipping : mpd.slice.12000-12999.json.zip
# 📦 Unzipping : mpd.slice.13000-13999.json.zip
# 📦 Unzipping : mpd.slice.14000-14999.json.zip
# 📦 Unzipping : mpd.slice.15000-15999.json.zip
# 📦 Unzipping : mpd.slice.16000-16999.json.zip
# 📦 Unzipping : mpd.slice.17000-17999.json.zip
# 📦 Unzipping : mpd.slice.18000-18999.json.zip
# 📦 Unzipping : mpd.slice.19000-19999.json.zip
# 📦 Unzipping : mpd.slice.2000-2999.json.zip
# 📦 Unzipping : mpd.slice.20000-20999.json.zip
# 📦 Unzipping : mpd.slice.21000-21999.json.zip
# 📦 Unzipping : mpd.slice.22000-22999.json.zip
# 📦 Unzipping : mpd.slice.23000-23999.json.zip
# 📦 Unzipping : mpd.slice.24000-24999.json.zip
# 📦 Unzipping : mpd.slice.25000-25999.json.zip
# 📦 Unzipping : mpd.slice.26000-26999.json.zip
# 📦 Unzipping : mpd.slice.27000-27999.json.zip
# 📦 Unzipping : mpd.slice.28000-28999.json.zip
# 📦 Unzipping : mpd.slice.29000-29999.json.zip
# 📦 Unzipping : mpd.slice.3000-3999.json.zip
# 📦 Unzipping : mpd.slice.30000-30999.json.zip
# 📦 Unzipping : mpd.slice.31000-31999.json.zip
# 📦 Unzipping : mpd.slice.32000-32999.json.zip
# 📦 Unzipping : mpd.slice.33000-33999.json.zip
# 📦 Unzipping : mpd.slice.34000-34999.json.zip
# 📦 Unzipping : mpd.slice.35000-35999.json.zip
# 📦 Unzipping : mpd.slice.36000-36999.json.zip
# 📦 Unzipping : mpd.slice.37000-37999.json.zip
# 📦 Unzipping : mpd.slice.38000-38999.json.zip
# 📦 Unzipping : mpd.slice.39000-39999.json.zip
# 📦 Unzipping : mpd.slice.4000-4999.json.zip
# 📦 Unzipping : mpd.slice.40000-40999.json.zip
# 📦 Unzipping : mpd.slice.41000-41999.json.zip
# 📦 Unzipping : mpd.slice.42000-42999.json.zip
# 📦 Unzipping : mpd.slice.43000-43999.json.zip
# 📦 Unzipping : mpd.slice.44000-44999.json.zip
# 📦 Unzipping : mpd.slice.45000-45999.json.zip
# 📦 Unzipping : mpd.slice.46000-46999.json.zip
# 📦 Unzipping : mpd.slice.47000-47999.json.zip
# 📦 Unzipping : mpd.slice.48000-48999.json.zip
# 📦 Unzipping : mpd.slice.49000-49999.json.zip
# 📦 Unzipping : mpd.slice.5000-5999.json.zip
# 📦 Unzipping : mpd.slice.50000-50999.json.zip
# 📦 Unzipping : mpd.slice.51000-51999.json.zip
# 📦 Unzipping : mpd.slice.52000-52999.json.zip
# 📦 Unzipping : mpd.slice.53000-53999.json.zip
# 📦 Unzipping : mpd.slice.54000-54999.json.zip
# 📦 Unzipping : mpd.slice.55000-55999.json.zip
# 📦 Unzipping : mpd.slice.56000-56999.json.zip
# 📦 Unzipping : mpd.slice.57000-57999.json.zip
# 📦 Unzipping : mpd.slice.58000-58999.json.zip
# 📦 Unzipping : mpd.slice.59000-59999.json.zip
# 📦 Unzipping : mpd.slice.6000-6999.json.zip
# 📦 Unzipping : mpd.slice.60000-60999.json.zip
# 📦 Unzipping : mpd.slice.61000-61999.json.zip
# 📦 Unzipping : mpd.slice.62000-62999.json.zip
# 📦 Unzipping : mpd.slice.63000-63999.json.zip
# 📦 Unzipping : mpd.slice.64000-64999.json.zip
# 📦 Unzipping : mpd.slice.65000-65999.json.zip
# 📦 Unzipping : mpd.slice.66000-66999.json.zip
# 📦 Unzipping : mpd.slice.67000-67999.json.zip
# 📦 Unzipping : mpd.slice.68000-68999.json.zip
# 📦 Unzipping : mpd.slice.69000-69999.json.zip
# 📦 Unzipping : mpd.slice.7000-7999.json.zip
# 📦 Unzipping : mpd.slice.70000-70999.json.zip
# 📦 Unzipping : mpd.slice.71000-71999.json.zip
# 📦 Unzipping : mpd.slice.72000-72999.json.zip
# 📦 Unzipping : mpd.slice.73000-73999.json.zip
# 📦 Unzipping : mpd.slice.74000-74999.json.zip
# 📦 Unzipping : mpd.slice.75000-75999.json.zip
# 📦 Unzipping : mpd.slice.76000-76999.json.zip
# 📦 Unzipping : mpd.slice.77000-77999.json.zip
# 📦 Unzipping : mpd.slice.78000-78999.json.zip
# 📦 Unzipping : mpd.slice.79000-79999.json.zip
# 📦 Unzipping : mpd.slice.8000-8999.json.zip
# 📦 Unzipping : mpd.slice.80000-80999.json.zip
# 📦 Unzipping : mpd.slice.81000-81999.json.zip
# 📦 Unzipping : mpd.slice.82000-82999.json.zip
# 📦 Unzipping : mpd.slice.83000-83999.json.zip
# 📦 Unzipping : mpd.slice.84000-84999.json.zip
# 📦 Unzipping : mpd.slice.85000-85999.json.zip
# 📦 Unzipping : mpd.slice.86000-86999.json.zip
# 📦 Unzipping : mpd.slice.87000-87999.json.zip
# 📦 Unzipping : mpd.slice.88000-88999.json.zip
# 📦 Unzipping : mpd.slice.89000-89999.json.zip
# 📦 Unzipping : mpd.slice.9000-9999.json.zip
# 📦 Unzipping : mpd.slice.90000-90999.json.zip
# 📦 Unzipping : mpd.slice.91000-91999.json.zip
# 📦 Unzipping : mpd.slice.92000-92999.json.zip
# 📦 Unzipping : mpd.slice.93000-93999.json.zip
# 📦 Unzipping : mpd.slice.94000-94999.json.zip
# 📦 Unzipping : mpd.slice.95000-95999.json.zip
# 📦 Unzipping : mpd.slice.96000-96999.json.zip
# 📦 Unzipping : mpd.slice.97000-97999.json.zip
# 📦 Unzipping : mpd.slice.98000-98999.json.zip
# 📦 Unzipping : mpd.slice.99000-99999.json.zip
# ✔️ Extraction terminée
#
# Nombre de fichiers JSON extraits : 120
# Exemples :
#  - mpd.slice.0-999.json
#  - mpd.slice.1000-1999.json
#  - mpd.slice.10000-10999.json
#  - mpd.slice.100000-100999.json
#  - mpd.slice.101000-101999.json
#
# Taille totale des JSON ≈ 3.78 Go

# %% [markdown]
# # Step 4 – Construire un document texte riche pour chaque playlist, pour LDA
#
# Objectif :
# - Parcourir les 120 fichiers `mpd.slice.*.json` dans `/content/mpd`.
# - Pour chaque playlist, créer un texte qui concatène :
#   - `name` (titre de la playlist)
#   - `description` (si elle existe)
#   - pour chaque track :
#     - `track_name`
#     - `artist_name`
#     - `album_name`
# - Stocker tout dans un DataFrame `df_playlists` avec les colonnes :
#   - `pid` : ID de la playlist
#   - `playlist_name` : titre
#   - `text` : document texte complet
#
# On limite le nombre total de playlists avec `MAX_PLAYLISTS`
# pour éviter les problèmes de RAM (tu peux augmenter ou diminuer).
# A la fin, on sauvegarde le résultat dans un fichier Parquet :
# `/content/df_playlists_text.parquet`.

# %%
import json
from pathlib import Path

import pandas as pd
from tqdm.auto import tqdm

mpd_dir = Path("/content/mpd")
json_files = sorted(mpd_dir.glob("mpd.slice.*.json"))

print(f"Nombre de fichiers JSON trouvés : {len(json_files)}")

MAX_PLAYLISTS = 50000  # comme avant

playlist_records = []
track_records = []      # 👈 NEW : une ligne par (playlist, track)
count_playlists = 0

for json_path in tqdm(json_files, desc="Lecture des slices"):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    playlists = data.get("playlists", [])

    for pl in playlists:
        pid = pl.get("pid")
        pl_name = (pl.get("name") or "").strip()
        pl_desc = (pl.get("description") or "").strip()

        track_tokens = []
        for tr in pl.get("tracks", []):
            track_uri   = (tr.get("track_uri")   or "").strip()
            track_name  = (tr.get("track_name")  or "").strip()
            artist_name = (tr.get("artist_name") or "").strip()
            album_name  = (tr.get("album_name")  or "").strip()

            # texte pour LDA
            track_tokens.extend([track_name, artist_name, album_name])

            # 👇 NEW : on garde une ligne par track
            track_records.append({
                "pid": pid,
                "track_uri": track_uri,
                "track_name": track_name,
                "artist_name": artist_name,
                "album_name": album_name
            })

        full_text_parts = [
            pl_name,
            pl_desc,
            " ".join(track_tokens)
        ]
        full_text = " ".join(part for part in full_text_parts if part)

        playlist_records.append(
            {
                "pid": pid,
                "playlist_name": pl_name,
                "text": full_text
            }
        )

        count_playlists += 1
        if count_playlists >= MAX_PLAYLISTS:
            break

    if count_playlists >= MAX_PLAYLISTS:
        break

print(f"\nNombre total de playlists chargées : {len(playlist_records)}")
print(f"Nombre total de (playlist, track) lignes : {len(track_records)}")

# DataFrame playlists
df_playlists = pd.DataFrame(playlist_records)
print(df_playlists.head())
print(df_playlists.shape)

# 👇 NEW : DataFrame tracks
df_pl_tracks = pd.DataFrame(track_records)
print(df_pl_tracks.head())
print(df_pl_tracks.shape)

# Sauvegarde
df_playlists.to_parquet("/content/df_playlists_text.parquet", index=False)
df_pl_tracks.to_parquet("/content/df_pl_tracks.parquet", index=False)

print("\n✅ df_playlists_text.parquet et df_pl_tracks.parquet sauvegardés")
# Out:
# Nombre de fichiers JSON trouvés : 120
# Lecture des slices:   0%|          | 0/120 [00:00<?, ?it/s]
# Nombre total de playlists chargées : 50000
# Nombre total de (playlist, track) lignes : 3353026
#    pid     playlist_name                                               text
# 0    0        Throwbacks  Throwbacks Lose Control (feat. Ciara & Fat Man...
# 1    1  Awesome Playlist  Awesome Playlist Eye of the Tiger Survivor Eye...
# 2    2            korean  korean Like You Hoody On And On GOOD (feat. EL...
# 3    3               mat  mat Danse macabre Camille Saint-Saëns French F...
# 4    4               90s  90s Tonight, Tonight The Smashing Pumpkins Mel...
# (50000, 3)
#    pid                             track_uri  \
# 0    0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1    0  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2    0  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3    0  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4    0  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                                    track_name        artist_name  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)      Missy Elliott
# 1                                       Toxic     Britney Spears
# 2                               Crazy In Love            Beyoncé
# 3                              Rock Your Body  Justin Timberlake
# 4                                It Wasn't Me             Shaggy
#
#                                      album_name
# 0                                  The Cookbook
# 1                                   In The Zone
# 2  Dangerously In Love (Alben für die Ewigkeit)
# 3                                     Justified
# 4                                      Hot Shot
# (3353026, 5)
#
# ✅ df_playlists_text.parquet et df_pl_tracks.parquet sauvegardés

# %% [markdown]
# # Step 5 — Nettoyage du texte + Vectorisation (Bag of Words)
#
# Objectif :
# - Recharger le DataFrame avec les 50k playlists.
# - Nettoyer légèrement le texte (`lowercase`, retirer caractères non-alphanumériques).
# - Construire une matrice sparse (documents × mots) avec `CountVectorizer`.
# - Configuration de CountVectorizer :
#   - `max_features=50000` : limite la taille du vocabulaire → RAM maîtrisée
#   - `min_df=10` : garde seulement les mots présents dans ≥ 10 playlists
#   - `max_df=0.5` : enlève les mots trop fréquents (présents dans >50% des playlists)
#
# Résultat :
# - Une matrice sparse `X_bow` qui servira d'entrée au modèle LDA.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import re

# (Re)charger le DataFrame sauvegardé
df_playlists = pd.read_parquet("/content/df_playlists_text.parquet")

print("Shape du DataFrame :", df_playlists.shape)

# 🔹🔹🔹 NEW : on garde 1 "slice" pour le test 🔹🔹🔹
# Ici : on prend les 1000 premières playlists comme set de test,
# et le reste sert à entraîner LDA (train).
TEST_SLICE_SIZE = 1000  # 1 "slice" ~ 1000 playlists

df_playlists_test = df_playlists.iloc[:TEST_SLICE_SIZE].copy()
df_playlists      = df_playlists.iloc[TEST_SLICE_SIZE:].copy()  # df_playlists = TRAIN


print("Shape TRAIN :", df_playlists.shape)
print("Shape TEST  :", df_playlists_test.shape)
# 🔹🔹🔹 FIN DU CHANGEMENT 🔹🔹🔹

# 1) Petit nettoyage du texte
def clean_text(text: str) -> str:
    text = text.lower()
    text = re.sub(r"[^a-z0-9]+", " ", text)
    return text

df_playlists["clean_text"] = df_playlists["text"].astype(str).apply(clean_text)

# 2) Vectorisation (Bag of Words)
vectorizer = CountVectorizer(
    max_features=50000,  # limite RAM
    min_df=10,           # mot doit être dans au moins 10 playlists
    max_df=0.5           # élimine les mots trop fréquents
)

print("⏳ Construction de la matrice BoW ...")
X_bow = vectorizer.fit_transform(df_playlists["clean_text"])
print("✔️ Matrice BoW créée")
print("Shape :", X_bow.shape)
# Out:
# Shape du DataFrame : (50000, 3)
# Shape TRAIN : (49000, 3)
# Shape TEST  : (1000, 3)
# ⏳ Construction de la matrice BoW ...
# ✔️ Matrice BoW créée
# Shape : (49000, 34320)

# %% [markdown]
# # Step 6 V2 — Entraîner un modèle LDA sur les playlists (12' do train)
# (**UPDATE** : L’erreur dit : OSError: [Errno 28] No space left on device → joblib essaie de créer des fichiers temporaires pour le parallélisme (n_jobs=-1), et ça sature le /tmp de Colab.)
#
# Objectif :
# - Appliquer un modèle LDA (Latent Dirichlet Allocation) sur la matrice BoW `X_bow`.
# - Obtenir pour chaque playlist un vecteur de dimension `N_TOPICS` qui représente
#   sa distribution de "topics" (thèmes musicaux).
# - Ces vecteurs serviront ensuite à calculer la similarité entre playlists.
#
# Paramètres :
# - `N_TOPICS = 50` (tu peux essayer 30, 50, 80…)
# - `learning_method="online"` : plus efficace sur des grandes matrices.
# - `max_iter=10` : nombre d'itérations d'apprentissage.

# %%
from sklearn.decomposition import LatentDirichletAllocation

N_TOPICS = 30  # un peu plus léger que 50

lda = LatentDirichletAllocation(
    n_components=N_TOPICS,
    learning_method="online",
    max_iter=10,
    random_state=42,
    n_jobs=1   # ❗ très important : plus de parallélisation → plus de tmp sur disque
)

print("⏳ Entraînement du modèle LDA (n_jobs=1) ...")
playlist_topic_matrix = lda.fit_transform(X_bow)
print("✔️ LDA entraîné")

print("Shape de la matrice topics (playlists × topics) :", playlist_topic_matrix.shape)
# Out:
# ⏳ Entraînement du modèle LDA (n_jobs=1) ...
# ✔️ LDA entraîné
# Shape de la matrice topics (playlists × topics) : (49000, 30)

# %% [markdown]
# # Step 6.1 — Donne les thèmes et le mots clefs => les dimensions

# %%
def print_top_words(model, feature_names, n_top_words=15):
    for topic_idx, topic in enumerate(model.components_):
        print(f"\n🟦 Topic #{topic_idx}")
        top_indices = topic.argsort()[::-1][:n_top_words]
        top_words = [feature_names[i] for i in top_indices]
        print("  " + ", ".join(top_words))

feature_names = vectorizer.get_feature_names_out()
print_top_words(lda, feature_names, n_top_words=15)
# Out:
# 🟦 Topic #0
#   eminem, lil, fetty, wap, wayne, khalifa, wiz, rich, drake, money, remix, young, big, dj, kid
#
# 🟦 Topic #1
#   vol, album, goes, pop, punk, punch, bts, five, pt, moment, beautiful, red, exo, mini, wings
#
# 🟦 Topic #2
#   remix, ep, flume, remixes, odesza, wonder, summer, down, so, high, oh, go, feel, light, night
#
# 🟦 Topic #3
#   original, soundtrack, motion, picture, cast, broadway, recording, hamilton, williams, john, harry, music, score, zimmer, hans
#
# 🟦 Topic #4
#   out, at, boy, fall, panic, twenty, disco, pilots, american, time, death, too, day, new, black
#
# 🟦 Topic #5
#   mix, remix, original, ep, vol, edit, remixes, dj, radio, daft, by, skrillex, club, punk, party
#
# 🟦 Topic #6
#   music, piano, vol, instrumental, songs, jazz, sleep, series, davis, tribute, sounds, michael, blue, miles, lindsey
#
# 🟦 Topic #7
#   high, deluxe, school, edition, maroon, mars, bruno, perry, cyrus, jason, taylor, musical, miley, katy, swift
#
# 🟦 Topic #8
#   soundtrack, little, frozen, beauty, mermaid, beast, king, original, lion, moana, disney, guys, mulan, tangled, hercules
#
# 🟦 Topic #9
#   night, luke, band, bryan, line, here, georgia, florida, brown, country, party, keith, jason, blake, young
#
# 🟦 Topic #10
#   op, piano, minor, bach, major, orchestra, concerto, string, suite, mozart, symphony, classical, quartet, cello, allegro
#
# 🟦 Topic #11
#   frank, ocean, tyler, mac, beach, orange, creator, teen, blonde, social, tame, american, impala, khalid, channel
#
# 🟦 Topic #12
#   remastered, john, best, single, edition, jackson, hits, can, greatest, michael, go, girl, time, get, anniversary
#
# 🟦 Topic #13
#   young, moon, night, dream, people, are, man, 1975, blood, black, an, del, elephant, head, little
#
# 🟦 Topic #14
#   live, worship, hillsong, god, united, jesus, are, come, free, will, grace, chris, here, name, passion
#
# 🟦 Topic #15
#   lil, uzi, vert, future, yachty, young, black, savage, migos, trap, gucci, drake, luv, scott, travis
#
# 🟦 Topic #16
#   de, la, el, los, en, del, banda, mi, que, amor, te, vivo, norte, lo, con
#
# 🟦 Topic #17
#   remastered, led, zeppelin, black, band, rolling, rock, stones, live, revival, van, tom, creedence, clearwater, ac
#
# 🟦 Topic #18
#   hits, best, greatest, band, live, man, george, johnny, time, country, collection, that, blues, essential, down
#
# 🟦 Topic #19
#   la, vol, best, le, underground, velvet, de, do, bop, les, prince, kids, martin, kidz, las
#
# 🟦 Topic #20
#   christmas, merry, sinatra, pentatonix, michael, bubl, santa, glee, frank, little, home, album, night, winter, nat
#
# 🟦 Topic #21
#   jay, notorious, 2pac, remastered, die, hits, greatest, da, dre, big, edition, dr, get, ice, black
#
# 🟦 Topic #22
#   down, park, days, grace, three, linkin, black, rise, death, against, metallica, hell, theory, deluxe, breaking
#
# 🟦 Topic #23
#   hot, red, remastered, blink, 182, sublime, peppers, chili, marley, weezer, green, day, blind, eye, american
#
# 🟦 Topic #24
#   remix, radio, edit, harris, calvin, mix, avicii, martin, chainsmokers, night, david, dj, vs, guetta, house
#
# 🟦 Topic #25
#   beyonc, edition, girl, deluxe, brown, rihanna, usher, album, chris, that, baby, get, pain, justin, nelly
#
# 🟦 Topic #26
#   la, el, de, remix, te, mi, que, tu, yankee, daddy, los, balvin, vol, amor, jam
#
# 🟦 Topic #27
#   justin, bieber, chainsmokers, know, selena, do, gomez, sheeran, ed, shawn, ariana, let, grande, edition, mendes
#
# 🟦 Topic #28
#   john, acoustic, live, james, mayer, heart, ed, sheeran, jack, at, head, lumineers, home, ben, ep
#
# 🟦 Topic #29
#   drake, kanye, west, cole, weeknd, kendrick, lamar, kid, late, rapper, views, childish, gambino, hills, chance

# %% [markdown]
# # Step 7 — Calculer la similarité entre playlists (cosine similarity)
#
# Objectif :
# - Utiliser la matrice `playlist_topic_matrix` (50000 × 30).
# - Pour une playlist donnée, calculer la similarité cosinus avec toutes les autres.
# - Trier les résultats pour obtenir les playlists les plus similaires.
# - Retourner pour chaque playlist choisie :
#   - `pid`
#   - `playlist_name`
#   - `similarity`
#
# Note :
# - On ne pré-calcule PAS la matrice 50000×50000 (trop lourde).
# - On calcule la similarité **uniquement pour une playlist à la demande**.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def get_similar_playlists(idx, top_k=10):
    """
    idx : index dans df_playlists de la playlist de référence
    top_k : nombre de playlists similaires à retourner
    """

    query_vec = playlist_topic_matrix[idx].reshape(1, -1)
    sims = cosine_similarity(query_vec, playlist_topic_matrix)[0]

    # Trier : du plus similaire au moins similaire
    sorted_idx = np.argsort(-sims)

    # On ignore la playlist elle-même
    sorted_idx = [i for i in sorted_idx if i != idx]

    top_idx = sorted_idx[:top_k]

    result = df_playlists.iloc[top_idx][["pid", "playlist_name"]].copy()
    result["similarity"] = sims[top_idx]

    return result

# Exemple : playlist index 0
example_idx = 0
print("Playlist de référence :", df_playlists.iloc[example_idx]["playlist_name"])
similar = get_similar_playlists(example_idx, top_k=5)
similar
# Out:
# Playlist de référence : disney
#           pid     playlist_name  similarity
# 43019    3019       Hindi songs    0.988460
# 10534  107534         Showtunes    0.988079
# 16421  112421            Kiddos    0.984878
# 33037   20037  Once Upon A Time    0.984846
# 16079  112079          Musicals    0.984197

# %% [markdown]
# Le tableau obtenu montre, pour une playlist de référence (“Throwbacks”), les playlists les plus similaires identifiées par notre modèle.
# - La similarité est calculée en comparant les vecteurs thématiques LDA de chaque playlist : lorsque deux playlists contiennent des morceaux, artistes et albums proches, leurs distributions de topics deviennent quasi identiques, ce qui produit une similarité cosinus très proche de 1.
# - Ainsi, les playlists “Middle School”, “TBT”, “Yonce” ou encore une autre “Throwbacks” apparaissent avec des scores supérieurs à 0.99, ce qui indique qu’elles appartiennent au même univers musical (nostalgie, R&B/pop des années 2000, oldies).
# - En bref, un score proche de 1 signifie que deux playlists partagent pratiquement les mêmes contenus musicaux et donc la même thématique.

# %% [markdown]
# # Step 9 — Sauvegarder tout le modèle dans un dossier unique
#
# Objectif :
# - Créer un dossier `playlist_model/`
# - Sauvegarder dedans :
#   - le modèle LDA
#   - le CountVectorizer
#   - la matrice topics des playlists
#   - le DataFrame (pid, nom, texte)
# - Zipper le dossier pour pouvoir le télécharger facilement
#
# Ce dossier contiendra TOUT pour recharger le système
# sans devoir ré-entraîner LDA ni recalculer BoW.

# %%
import joblib
import pandas as pd
import os
import shutil

# 1) Créer dossier propre
MODEL_DIR = "/content/playlist_model"
os.makedirs(MODEL_DIR, exist_ok=True)

# 2) Sauvegarder les objets sklearn
joblib.dump(lda, os.path.join(MODEL_DIR, "lda_model.joblib"))
joblib.dump(vectorizer, os.path.join(MODEL_DIR, "vectorizer.joblib"))
joblib.dump(playlist_topic_matrix, os.path.join(MODEL_DIR, "playlist_topic_matrix.joblib"))

# 3) Sauvegarder les DataFrames nécessaires
#    ⚠️ Ici on suppose que df_playlists = TRAIN
#    et que df_playlists_test existe déjà (ta slice mise de côté)
df_playlists.to_parquet(os.path.join(MODEL_DIR, "df_playlists.parquet"), index=False)
df_pl_tracks.to_parquet(os.path.join(MODEL_DIR, "df_pl_tracks.parquet"), index=False)
df_playlists_test.to_parquet(os.path.join(MODEL_DIR, "test_slices.parquet"), index=False)

print("✔️ df_playlists.parquet (TRAIN) sauvegardé")
print("✔️ df_pl_tracks.parquet sauvegardé")
print("✔️ test_slices.parquet (TEST) sauvegardé")

# 4) Créer un ZIP téléchargeable
ZIP_PATH = "/content/playlist_model.zip"
shutil.make_archive("/content/playlist_model", 'zip', MODEL_DIR)

print("📦 ZIP créé :", ZIP_PATH)
# Out:
# ✔️ df_playlists.parquet (TRAIN) sauvegardé
# ✔️ df_pl_tracks.parquet sauvegardé
# ✔️ test_slices.parquet (TEST) sauvegardé
# 📦 ZIP créé : /content/playlist_model.zip

# %% [markdown]
# # Step 10 — Recharger le modèle complet depuis le dossier playlist_model
# Après cette étape, tu peux directement appeler get_similar_playlists().

# %%
import joblib
import pandas as pd

MODEL_DIR = "/content/playlist_model"  # ou le dossier dans ton Drive

lda = joblib.load(f"{MODEL_DIR}/lda_model.joblib")
vectorizer = joblib.load(f"{MODEL_DIR}/vectorizer.joblib")
playlist_topic_matrix = joblib.load(f"{MODEL_DIR}/playlist_topic_matrix.joblib")
df_playlists = pd.read_parquet(f"{MODEL_DIR}/df_playlists.parquet")

print("✔️ Modèle complètement rechargé")
